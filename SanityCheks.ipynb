# %%
# %sql
USE CATALOG workspace;
USE SCHEMA schema_drift;
SELECT COUNT(*) FROM demo_cust_bronze_sd;

# %%
# %sql
SELECT COUNT(DISTINCT CustomerID) FROM demo_cust_bronze_sd;

# %%
# %sql
SELECT COUNT(*) AS rescued_non_null
FROM demo_cust_bronze_sd
WHERE _rescued_data IS NOT NULL AND _rescued_data != 'null';

# %%
# %sql
DESC demo_cust_bronze_sd;

# %%
# %sql
SELECT
  (SELECT COUNT(*) FROM demo_cust_bronze_sd) AS bronze_count,
  (SELECT COUNT(*) FROM demo_cust_silver_sd) AS silver_count;

# %%
# %sql
DESC demo_cust_silver_sd;

# %%
# %sql
SELECT CustomerID, CreditScore
FROM demo_cust_silver_sd
WHERE CreditScore IS NOT NULL
LIMIT 10;

# %%
# %sql
SELECT DISTINCT SignupDate
FROM demo_cust_silver_sd
ORDER BY SignupDate
LIMIT 10;

# %%
# %sql
SELECT CustomerID, Age, Gender, LoyaltyStatus
FROM demo_cust_silver_sd
WHERE Age IS NOT NULL
LIMIT 10;

# %%
# %sql
SELECT COUNT(*) AS silver_rescued
FROM demo_cust_silver_sd
WHERE _rescued_data IS NOT NULL AND _rescued_data != 'null';

# %%
# %sql
SELECT
  MIN(ingestion_datetime) AS first_load,
  MAX(ingestion_datetime) AS last_load,
  COUNT(*) AS total_records,
  COUNT(DISTINCT source_filename) AS files_seen
FROM demo_cust_bronze_sd;
